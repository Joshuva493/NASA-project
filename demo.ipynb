# %%
# !pip install pymysql

# %%
import pymysql


connection = pymysql.connect(
    host = "localhost",
    user = 'root',
    password = "Josh##2005",
    database = "astro"
)


cursor = connection.cursor()

# %%
asteroids = [{"id":2415949},{"id":3160747},{"id":3309828}]

# %%
cursor.execute("create table close_approach (id INT)")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 cursor.execute("create table asteroids (id INT)")
#
# NameError: name 'cursor' is not defined

# %%
insert_query = """insert into close_approach (id)values(%s)"""
for i in  asteroids:
       values = (i['id'])

       cursor.execute(insert_query,values)
connection.commit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 insert_query = """insert into asteroids(id)values(%s)"""
# ----> 2 for i in  asteroids:
#       3        values = (i['id'])
#       5        cursor.execute(insert_query,values)
#
# NameError: name 'asteroids' is not defined
